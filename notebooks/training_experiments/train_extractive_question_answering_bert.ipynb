# %% [markdown]
# ### Try with question answering using BERT to perform extractive question answering

# %%
## based on HuggingFace documentations and tutorials

# %%
import pandas as pd
import numpy as np
import os
import ast
import evaluate
import collections
import evaluate
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
from datasets import Dataset, load_dataset
from tqdm.auto import tqdm

# %% [markdown]
# ### Load our datasets

# %%
abs_path = os.path.abspath('../../')
path_to_data = 'data/processed'

# %%
data_files = {
    "train": os.path.join(abs_path, path_to_data, 'train.csv'),
    "validation":  os.path.join(abs_path, path_to_data, 'valid.csv'),
    "test": os.path.join(abs_path, path_to_data, 'test.csv')
}

# %%
dataset = load_dataset("csv", data_files=data_files)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'context', 'answer', 'voted_label', 'start_end_indexes'],
#         num_rows: 11137
#     })
#     validation: Dataset({
#         features: ['question', 'context', 'answer', 'voted_label', 'start_end_indexes'],
#         num_rows: 1376
#     })
#     test: Dataset({
#         features: ['question', 'context', 'answer', 'voted_label', 'start_end_indexes'],
#         num_rows: 1314
#     })
# })

# %%
def convert_to_tuples(example):
    """
    when saved as dataframes, tuples were converted to string so we need to revert that
    """
    example['start_end_indexes'] = ast.literal_eval(example['start_end_indexes'])
    return example

# %%
def format_answer(example):
    """
    It was easier to format the dataset as expected by the model
    """
    example['answers'] = {'text': [example['answer']], 'answer_start': [example['start_end_indexes'][0]]}
    return example

# %%
dataset = dataset.map(convert_to_tuples)
dataset = dataset.map(format_answer)

# %%
dataset['train'] = dataset['train'].add_column('id', [str(i)*3 for i in range(len(dataset['train']))])
dataset['validation'] = dataset['validation'].add_column('id', [str(i)*3 for i in range(len(dataset['validation']))])
dataset['test'] = dataset['test'].add_column('id', [str(i)*3 for i in range(len(dataset['test']))])

# %% [markdown]
# ## Let's preprocess the data with tokenizer

# %%
model_checkpoint = "distilbert/distilbert-base-uncased" # most common arquitecture for extractive question answering, pretrained with distillation technique
#"distilbert-base-cased-distilled-squad"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
tokenizer.is_fast
# Out:
# True

# %%
max_length = 500
stride = 130

# %%
question = dataset["train"][0]["question"]
context = dataset["train"][0]["context"]

# %%
inputs = tokenizer(question, context)

# %%
tokenizer.decode(inputs["input_ids"])
# Out:
# "[CLS] what is ( are ) glaucoma? [SEP] glaucoma is a group of diseases that can damage the eye ' s optic nerve and result in vision loss and blindness. the most common form of the disease is open - angle glaucoma. with early treatment, you can often protect your eyes against serious vision loss. ( watch the video to learn more about glaucoma. to enlarge the video, click the brackets in the lower right - hand corner. to reduce the video, press the escape ( esc ) button on your keyboard. ) see this graphic for a quick overview of glaucoma, including how many people it affects, whos at risk, what to do if you have it, and how to learn more. see a glossary of glaucoma terms. [SEP]"

# %%
def preprocess_training_examples(examples):
    """
    Function to preprocess training examples,
    Tokenization, splitting, and start_end index identification
    """
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second",
        stride=stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    sample_map = inputs.pop("overflow_to_sample_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        sample_idx = sample_map[i]
        answer = answers[sample_idx]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        # Find the start and end of the context
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label is (0, 0)
        if offset[context_start][0] > start_char or offset[context_end][1] < end_char or answer=='no-answer':
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %% [markdown]
# ### Processing training dataset

# %%
train_dataset = dataset['train'].map(
    preprocess_training_examples,
    batched=True,
    remove_columns=dataset["train"].column_names
)
# Out:
# Map:   0%|          | 0/11137 [00:00<?, ? examples/s]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask', 'start_positions', 'end_positions'],
#     num_rows: 11559
# })

# %%
def preprocess_validation_examples(examples):
    """
    Processing for validation set, 
    A little bit different from  training
    """
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second",
        stride=stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    sample_map = inputs.pop("overflow_to_sample_mapping")
    example_ids = []

    for i in range(len(inputs["input_ids"])):
        sample_idx = sample_map[i]
        example_ids.append(examples["id"][sample_idx])

        sequence_ids = inputs.sequence_ids(i)
        offset = inputs["offset_mapping"][i]
        inputs["offset_mapping"][i] = [
            o if sequence_ids[k] == 1 else None for k, o in enumerate(offset)
        ]

    inputs["example_id"] = example_ids
    return inputs

# %% [markdown]
# ### Processing validation dataset

# %%
validation_dataset = dataset['validation'].map(
    preprocess_validation_examples,
    batched=True,
    remove_columns=dataset["validation"].column_names
)

# %%
####
### Evaluation metric to run on the validation dataset
####

metric = evaluate.load("squad")
n_best = 50
max_answer_length = 512

def compute_metrics(start_logits, end_logits, features, examples):
    example_to_features = collections.defaultdict(list)
    for idx, feature in enumerate(features):
        example_to_features[feature["example_id"]].append(idx)

    predicted_answers = []
    for example in tqdm(examples):
        example_id = example["id"]
        context = example["context"]
        answers = []

        # Loop through all features associated with that example
        for feature_index in example_to_features[example_id]:
            start_logit = start_logits[feature_index]
            end_logit = end_logits[feature_index]
            offsets = features[feature_index]["offset_mapping"]

            start_indexes = np.argsort(start_logit)[-1 : -n_best - 1 : -1].tolist()
            end_indexes = np.argsort(end_logit)[-1 : -n_best - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Skip answers that are not fully in the context
                    if offsets[start_index] is None or offsets[end_index] is None:
                        continue
                    # Skip answers with a length that is either < 0 or > max_answer_length
                    if (
                        end_index < start_index
                        or end_index - start_index + 1 > max_answer_length
                    ):
                        continue

                    answer = {
                        "text": context[offsets[start_index][0] : offsets[end_index][1]],
                        "logit_score": start_logit[start_index] + end_logit[end_index],
                    }
                    answers.append(answer)

        # Select the answer with the best score
        if len(answers) > 0:
            best_answer = max(answers, key=lambda x: x["logit_score"])
            predicted_answers.append(
                {"id": example_id, "prediction_text": best_answer["text"]}
            )
        else:
            predicted_answers.append({"id": example_id, "prediction_text": "no-answer"})

    theoretical_answers = [{"id": ex["id"], "answers": ex["answers"]} for ex in examples]
    return metric.compute(predictions=predicted_answers, references=theoretical_answers)

# %% [markdown]
# ### Perform Fine tuning

# %%
import torch
from torch.utils.data import DataLoader
from transformers import default_data_collator
from torch.optim import AdamW
from accelerate import Accelerator
from transformers import get_scheduler
from tqdm.auto import tqdm

# %%
model = AutoModelForQuestionAnswering.from_pretrained(model_checkpoint)
# Out:
# Some weights of DistilBertForQuestionAnswering were not initialized from the model checkpoint at distilbert/distilbert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
train_dataset.set_format("torch")
validation_set = validation_dataset.remove_columns(["example_id", "offset_mapping"])
validation_set.set_format("torch")

# %%
train_dataloader = DataLoader(
    train_dataset,
    shuffle=True,
    collate_fn=default_data_collator,
    batch_size=8,
)
eval_dataloader = DataLoader(
    validation_set, collate_fn=default_data_collator, batch_size=8
)

# %%
optimizer = AdamW(model.parameters(), lr=2e-5)

# %%
accelerator = Accelerator(mixed_precision ='fp16', gradient_accumulation_steps=1)
model, optimizer, train_dataloader, eval_dataloader = accelerator.prepare(
    model, optimizer, train_dataloader, eval_dataloader
)

# %%
num_train_epochs = 2
num_update_steps_per_epoch = len(train_dataloader)
num_training_steps = num_train_epochs * num_update_steps_per_epoch

lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps,
)

# %%
output_dir = os.path.join(abs_path,'models', "bert-finetuned-medicalbot-accelerate_2")
output_dir
# Out:
# '/mnt/d/projects/medical_assistant_bot_assignment/models/bert-finetuned-medicalbot-accelerate_2'

# %% [markdown]
# ### Run fine tuning for 2-3 epochs

# %%
progress_bar = tqdm(range(num_training_steps))

best_f1_score = 0
for epoch in range(num_train_epochs):
    # Training
    model.train()
    for step, batch in enumerate(train_dataloader):
        outputs = model(**batch)
        loss = outputs.loss
        accelerator.backward(loss)

        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)

    # Evaluation
    model.eval()
    start_logits = []
    end_logits = []
    accelerator.print("Evaluation!")
    for batch in tqdm(eval_dataloader):
        with torch.no_grad():
            outputs = model(**batch)

        start_logits.append(accelerator.gather(outputs.start_logits).cpu().numpy())
        end_logits.append(accelerator.gather(outputs.end_logits).cpu().numpy())

    start_logits = np.concatenate(start_logits)
    end_logits = np.concatenate(end_logits)
    start_logits = start_logits[: len(validation_dataset)]
    end_logits = end_logits[: len(validation_dataset)]

    metrics = compute_metrics(
        start_logits, end_logits, validation_dataset, dataset["validation"]
    )
    print(f"epoch {epoch}:", metrics)

    # Save best
    if metrics['f1'] > best_f1_score:
        print('new best model saved')
        best_f1_score = metrics['f1']
        accelerator.wait_for_everyone()
        unwrapped_model = accelerator.unwrap_model(model)
        unwrapped_model.save_pretrained(output_dir, save_function=accelerator.save)
# Out:
#   0%|          | 0/2890 [00:00<?, ?it/s]
# Evaluation!
#   0%|          | 0/180 [00:00<?, ?it/s]
#   0%|          | 0/1376 [00:00<?, ?it/s]
# epoch 0: {'exact_match': 40.18895348837209, 'f1': 70.19901438065072}
# new best model saved
# Evaluation!
#   0%|          | 0/180 [00:00<?, ?it/s]
#   0%|          | 0/1376 [00:00<?, ?it/s]
# epoch 1: {'exact_match': 40.18895348837209, 'f1': 70.19901438065072}

# %% [markdown]
# ### Let's try with some questions

# %%
from transformers import pipeline

# %%
test_dataset = pd.read_csv(os.path.join(abs_path, 'data/processed', 'test.csv'))

# %%
# Replace this with your own checkpoint
model_checkpoint = os.path.join(abs_path, "models/bert-finetuned-medicalbot-accelerate_2/")
question_answerer = pipeline("question-answering", model=model_checkpoint, tokenizer=tokenizer, device='cuda')

# %%
test_dataset.iloc[[961,985,41,80,112,146]]
# Out:
#                                               question  \
# 961    How many people are affected by Ochoa syndrome?
# 985  What are the genetic changes related to Danon ...
# 41                  Who is at risk for Neuroblastoma??
# 80                            What is (are) Pemphigus?
# 112                 Do you have information about MRSA
# 146              What is (are) Heart Disease in Women?
#
#                                                context  \
# 961  Ochoa syndrome is a rare disorder. About 150 c...
# 985  Danon disease is caused by mutations in the LA...
# 41   The risk factors for neuroblastoma are not known.
# 80   Pemphigus is an autoimmune disorder. If you ha...
# 112  Summary : MRSA stands for methicillin-resistan...
# 146  In the United States, 1 in 4 women dies from h...
#
#                                                 answer            voted_label  \
# 961  About 150 cases have been reported in the medi...          ochoa_related
# 985  Danon disease is caused by mutations in the LA...          danon_related
# 41                                           no-answer  neuroblastoma_outlook
# 80   Pemphigus is an autoimmune disorder. If you ha...      pemphigus_chronic
# 112  Summary : MRSA stands for methicillin-resistan...                   mrsa
# 146  In the United States, 1 in 4 women dies from h...            women_heart
#
#     start_end_indexes
# 961          (35, 61)
# 985            (0, 0)
# 41             (0, 0)
# 80           (0, 315)
# 112            (0, 0)
# 146            (0, 0)

# %%
question = "How many people are affected by Ochoa syndrome?	"
context = "Ochoa syndrome is a rare disorder. About 150 cases have been reported in the medical literature."
question_answerer(question=question, context=context)['answer']
# Out:
# 'About 150 cases have been reported in the medical literature.'

# %%
question = "What is (are) Heart Disease in Women?"
context = "In the United States, 1 in 4 women dies from heart disease. The most common cause of heart disease in both men and women is narrowing or blockage of the coronary arteries, the blood vessels that supply blood to the heart itself. This is called coronary artery disease, and it happens slowly over time. It's the major reason people have heart attacks.    Heart diseases that affect women more than men include       - Coronary microvascular disease (MVD) - a problem that affects the heart's tiny arteries    - Broken heart syndrome - extreme emotional stress leading to severe but often short-term heart muscle failure       The older a woman gets, the more likely she is to get heart disease. But women of all ages should be concerned about heart disease. All women can take steps to prevent it by practicing healthy lifestyle habits.     NIH: National Heart, Lung, and Blood Institute"
question_answerer(question=question, context=context)['answer']
# Out:
# 'In the United States, 1 in 4 women dies from heart disease.'

# %%
question = "Is allergic asthma inherited?"
context = "Allergic asthma can be passed through generations in families, but the inheritance pattern is unknown. People with mutations in one or more of the associated genes inherit an increased risk of allergic asthma, not the condition itself. Because allergic asthma is a complex condition influenced by genetic and environmental factors, not all people with a mutation in an asthma-associated gene will develop the disorder."
question_answerer(question=question, context=context)['answer']
# Out:
# 'Allergic asthma can be passed through generations in families, but the inheritance'

# %%
question = "What is allergic asthma?"
context = "Because allergic asthma is a complex condition influenced by genetic and environmental factors, not all people with a mutation in an asthma-associated gene will develop the disorder."
question_answerer(question=question, context=context)['answer']
# Out:
# 'Because allergic'

# %%
dataset['train']['question']
# Out:
# ['What is (are) Glaucoma?',
#  'Who is at risk for Glaucoma??',
#  'How to prevent Glaucoma?',
#  'What are the symptoms of Glaucoma?',
#  'What are the treatments for Glaucoma?',
#  'what research (or clinical trials) is being done for Glaucoma?',
#  'What is (are) High Blood Pressure?',
#  'What are the treatments for High Blood Pressure?',
#  'How to prevent High Blood Pressure?',
#  "What is (are) Paget's Disease of Bone?",
#  "What are the symptoms of Paget's Disease of Bone?",
#  "How to diagnose Paget's Disease of Bone?",
#  "What are the complications of Paget's Disease of Bone?",
#  "What are the treatments for Paget's Disease of Bone?",
#  'What is (are) Urinary Tract Infections?',
#  'What are the symptoms of Urinary Tract Infections?',
#  'Who is at risk for Urinary Tract Infections??',
#  'What are the treatments for Urinary Tract Infections?',
#  'What is (are) Alcohol Use and Older Adults?',
#  'What are the symptoms of Alcohol Use and Older Adults?',
#  'What are the treatments for Alcohol Use and Older Adults?',
#  'Where to find support for people with Alcohol Use and Older Adults?',
#  'What causes Osteoarthritis?',
#  'What is (are) Osteoarthritis?',
#  'How many people are affected by Osteoarthritis?',
#  'What are the symptoms of Osteoarthritis?',
#  'How to diagnose Osteoarthritis?',
#  'What are the treatments for Osteoarthritis?',
#  'What is (are) Problems with Taste?',
#  'How many people are affected by Problems with Taste?',
#  'What causes Problems with Taste?',
#  'How to prevent Problems with Taste?',
#  'How to diagnose Problems with Taste?',
#  'What are the treatments for Problems with Taste?',
#  'what research (or clinical trials) is being done for Problems with Taste?',
#  'what research (or clinical trials) is being done for Anxiety Disorders?',
#  'How many people are affected by Anxiety Disorders?',
#  'What is (are) Anxiety Disorders?',
#  'Who is at risk for Anxiety Disorders??',
#  'What are the treatments for Anxiety Disorders?',
#  'What is (are) Diabetes?',
#  'What are the symptoms of Diabetes?',
#  'What causes Diabetes?',
#  'What are the treatments for Diabetes?',
#  'Who is at risk for Diabetes??',
#  'What is (are) Medicare and Continuing Care?',
#  'What to do for Medicare and Continuing Care?',
#  'What is (are) Knee Replacement?',
#  'What are the complications of Knee Replacement?',
#  'What are the treatments for Knee Replacement?',
#  'Who is at risk for Knee Replacement??',
#  'What is (are) Quitting Smoking for Older Adults?',
#  'What causes Quitting Smoking for Older Adults?',
#  'What is (are) Prostate Cancer?',
#  'Who is at risk for Prostate Cancer??',
#  'What are the treatments for Prostate Cancer?',
#  'How many people are affected by Prostate Cancer?',
#  'What causes Prostate Cancer?',
#  'What are the symptoms of Prostate Cancer?',
#  'How to diagnose Prostate Cancer?',
#  'What is (are) Dry Mouth?',
#  'What causes Dry Mouth?',
#  'What are the symptoms of Dry Mouth?',
#  'What are the treatments for Dry Mouth?',
#  'What are the symptoms of Osteoporosis?',
#  'what research (or clinical trials) is being done for Osteoporosis?',
#  'What is (are) Osteoporosis?',
#  'Who is at risk for Osteoporosis??',
#  'How to diagnose Osteoporosis?',
#  'What are the treatments for Osteoporosis?',
#  'What is (are) Kidney Disease?',
#  'What causes Kidney Disease?',
#  'Who is at risk for Kidney Disease??',
#  'What are the symptoms of Kidney Disease?',
#  'What are the treatments for Kidney Disease?',
#  'what research (or clinical trials) is being done for Kidney Disease?',
#  "what research (or clinical trials) is being done for Alzheimer's Disease?",
#  "What is (are) Alzheimer's Disease?",
#  "What causes Alzheimer's Disease?",
#  "How to diagnose Alzheimer's Disease?",
#  "What are the treatments for Alzheimer's Disease?",
#  "How to prevent Alzheimer's Disease?",
#  'How many people are affected by Hearing Loss?',
#  'What is (are) Hearing Loss?',
#  'What causes Hearing Loss?',
#  'How to prevent Hearing Loss?',
#  'What are the treatments for Hearing Loss?',
#  'What is (are) Low Vision?',
#  'What causes Low Vision?',
#  'What are the symptoms of Low Vision?',
#  'Who is at risk for Low Vision??',
#  'What causes COPD?',
#  'What is (are) COPD?',
#  'What are the symptoms of COPD?',
#  'How to diagnose COPD?',
#  'What are the treatments for COPD?',
#  'How to prevent COPD?',
#  'What is (are) Diabetic Retinopathy?',
#  'What causes Diabetic Retinopathy?',
#  'Who is at risk for Diabetic Retinopathy??',
#  'What are the symptoms of Diabetic Retinopathy?',
#  'What are the treatments for Diabetic Retinopathy?',
#  'what research (or clinical trials) is being done for Diabetic Retinopathy?',
#  'What to do for Diabetic Retinopathy?',
#  'What is (are) Depression?',
#  'Who is at risk for Depression??',
#  'What are the symptoms of Depression?',
#  'What are the treatments for Depression?',
#  'What are the treatments for Breast Cancer?',
#  'What is (are) Breast Cancer?',
#  'Who is at risk for Breast Cancer??',
#  'What are the symptoms of Breast Cancer?',
#  'How to prevent Breast Cancer?',
#  'what research (or clinical trials) is being done for Breast Cancer?',
#  'What is (are) Colorectal Cancer?',
#  'What are the treatments for Colorectal Cancer?',
#  'How many people are affected by Colorectal Cancer?',
#  'Who is at risk for Colorectal Cancer??',
#  'What are the symptoms of Colorectal Cancer?',
#  'How to prevent Colorectal Cancer?',
#  "what research (or clinical trials) is being done for Parkinson's Disease?",
#  'What are the treatments for Leukemia?',
#  'What is (are) Leukemia?',
#  'Who is at risk for Leukemia??',
#  'What are the symptoms of Leukemia?',
#  'How to diagnose Leukemia?',
#  'what research (or clinical trials) is being done for Leukemia?',
#  'What are the treatments for Lung Cancer?',
#  'what research (or clinical trials) is being done for Lung Cancer?',
#  'What is (are) Lung Cancer?',
#  'What causes Lung Cancer?',
#  'Who is at risk for Lung Cancer??',
#  'What are the symptoms of Lung Cancer?',
#  'How to diagnose Lung Cancer?',
#  'What causes Urinary Incontinence?',
#  'How to diagnose Urinary Incontinence?',
#  'What is (are) Urinary Incontinence?',
#  'What are the treatments for Urinary Incontinence?',
#  'What is (are) Stroke?',
#  'Who is at risk for Stroke??',
#  'What are the symptoms of Stroke?',
#  'How to diagnose Stroke?',
#  'What are the treatments for Stroke?',
#  'what research (or clinical trials) is being done for Stroke?',
#  'what research (or clinical trials) is being done for Psoriasis?',
#  'What is (are) High Blood Cholesterol?',
#  'How to diagnose High Blood Cholesterol?',
#  'What are the treatments for High Blood Cholesterol?',
#  'What is (are) Peripheral Arterial Disease (P.A.D.)?',
#  'What causes Peripheral Arterial Disease (P.A.D.)?',
#  'Who is at risk for Peripheral Arterial Disease (P.A.D.)??',
#  'What are the symptoms of Peripheral Arterial Disease (P.A.D.)?',
#  'How to prevent Peripheral Arterial Disease (P.A.D.)?',
#  'what research (or clinical trials) is being done for Peripheral Arterial Disease (P.A.D.)?',
#  'What is (are) Prescription and Illicit Drug Abuse?',
#  'What are the symptoms of Prescription and Illicit Drug Abuse?',
#  'What causes Prescription and Illicit Drug Abuse?',
#  'What are the treatments for Prescription and Illicit Drug Abuse?',
#  'What is (are) Cataract?',
#  'Who is at risk for Cataract??',
#  'What are the symptoms of Cataract?',
#  'What are the treatments for Cataract?',
#  'What is (are) Creating a Family Health History?',
#  'What causes Creating a Family Health History?',
#  'How to prevent Creating a Family Health History?',
#  'How to diagnose Creating a Family Health History?',
#  'What causes Shingles?',
#  'What are the treatments for Shingles?',
#  'What is (are) Shingles?',
#  'Who is at risk for Shingles??',
#  'What are the symptoms of Shingles?',
#  'How to diagnose Shingles?',
#  'What are the complications of Shingles?',
#  'How to prevent Shingles?',
#  'What is (are) Heart Attack?',
#  'How to diagnose Heart Attack?',
#  'What causes Heart Attack?',
#  'What are the symptoms of Heart Attack?',
#  'How many people are affected by Heart Attack?',
#  'Who is at risk for Heart Attack??',
#  'What are the treatments for Heart Attack?',
#  'What is (are) Skin Cancer?',
#  'Who is at risk for Skin Cancer??',
#  'What are the symptoms of Skin Cancer?',
#  'What are the treatments for Skin Cancer?',
#  'what research (or clinical trials) is being done for Skin Cancer?',
#  'What are the symptoms of Gout?',
#  'What are the treatments for Gout?',
#  'What is (are) Gout?',
#  'What causes Gout?',
#  'Who is at risk for Gout??',
#  'How to diagnose Gout?',
#  "What is (are) Alzheimer's Caregiving?",
#  "What are the treatments for Alzheimer's Caregiving?",
#  "How to diagnose Alzheimer's Caregiving?",
#  "What to do for Alzheimer's Caregiving?",
#  'What are the symptoms of Dry Eye?',
#  'What is (are) Dry Eye?',
#  'What causes Dry Eye?',
#  'How to diagnose Dry Eye?',
#  'What are the treatments for Dry Eye?',
#  'What are the symptoms of Gum (Periodontal) Disease?',
#  'What is (are) Gum (Periodontal) Disease?',
#  'What causes Gum (Periodontal) Disease?',
#  'What are the treatments for Gum (Periodontal) Disease?',
#  'Who is at risk for Gum (Periodontal) Disease??',
#  'How to prevent Gum (Periodontal) Disease?',
#  'How to diagnose Gum (Periodontal) Disease?',
#  'What is (are) Heart Failure?',
#  'What are the symptoms of Heart Failure?',
#  'What are the treatments for Heart Failure?',
#  'What causes Heart Failure?',
#  'How many people are affected by Heart Failure?',
#  'Who is at risk for Heart Failure??',
#  'How to prevent Heart Failure?',
#  'How to diagnose Heart Failure?',
#  'What is the outlook for Breast Cancer?',
#  'Who is at risk for Hairy Cell Leukemia??',
#  'What are the symptoms of Hairy Cell Leukemia?',
#  'What is the outlook for Hairy Cell Leukemia?',
#  'What are the stages of Hairy Cell Leukemia?',
#  'what research (or clinical trials) is being done for Hairy Cell Leukemia?',
#  'What is (are) Vulvar Cancer?',
#  'What are the symptoms of Vulvar Cancer?',
#  'How to diagnose Vulvar Cancer?',
#  'What is the outlook for Vulvar Cancer?',
#  'What is (are) Atypical Chronic Myelogenous Leukemia?',
#  'What are the symptoms of Atypical Chronic Myelogenous Leukemia?',
#  'What is the outlook for Atypical Chronic Myelogenous Leukemia?',
#  'What are the treatments for Atypical Chronic Myelogenous Leukemia?',
#  'Who is at risk for Childhood Soft Tissue Sarcoma??',
#  'What are the symptoms of Childhood Soft Tissue Sarcoma?',
#  'What is the outlook for Childhood Soft Tissue Sarcoma?',
#  'what research (or clinical trials) is being done for Childhood Soft Tissue Sarcoma?',
#  'What is (are) Thymoma and Thymic Carcinoma?',
#  'What are the symptoms of Thymoma and Thymic Carcinoma?',
#  'What is the outlook for Thymoma and Thymic Carcinoma?',
#  'what research (or clinical trials) is being done for Thymoma and Thymic Carcinoma?',
#  'What are the symptoms of Wilms Tumor and Other Childhood Kidney Tumors?',
#  'What is the outlook for Wilms Tumor and Other Childhood Kidney Tumors?',
#  'What is (are) Anal Cancer?',
#  'Who is at risk for Anal Cancer??',
#  'What are the symptoms of Anal Cancer?',
#  'How to diagnose Anal Cancer?',
#  'What is the outlook for Anal Cancer?',
#  'What causes Childhood Extracranial Germ Cell Tumors?',
#  'Who is at risk for Childhood Extracranial Germ Cell Tumors??',
#  'What are the symptoms of Childhood Extracranial Germ Cell Tumors?',
#  'What is the outlook for Childhood Extracranial Germ Cell Tumors?',
#  'What is (are) Uterine Sarcoma?',
#  'Who is at risk for Uterine Sarcoma??',
#  'What are the symptoms of Uterine Sarcoma?',
#  'What is the outlook for Uterine Sarcoma?',
#  'What is (are) Polycythemia Vera?',
#  'What are the symptoms of Polycythemia Vera?',
#  'How to diagnose Polycythemia Vera?',
#  'What are the treatments for Polycythemia Vera?',
#  'What is (are) Chronic Myelogenous Leukemia?',
#  'What are the symptoms of Chronic Myelogenous Leukemia?',
#  'What are the genetic changes related to Chronic Myelogenous Leukemia?',
#  'How to diagnose Chronic Myelogenous Leukemia?',
#  'What is the outlook for Chronic Myelogenous Leukemia?',
#  'What are the stages of Chronic Myelogenous Leukemia?',
#  'What is (are) Merkel Cell Carcinoma?',
#  'Who is at risk for Merkel Cell Carcinoma??',
#  'What are the symptoms of Merkel Cell Carcinoma?',
#  'How to diagnose Merkel Cell Carcinoma?',
#  'What is the outlook for Merkel Cell Carcinoma?',
#  'what research (or clinical trials) is being done for Merkel Cell Carcinoma?',
#  'What is (are) Extragonadal Germ Cell Tumors?',
#  'Who is at risk for Extragonadal Germ Cell Tumors??',
#  'What are the symptoms of Extragonadal Germ Cell Tumors?',
#  'What is the outlook for Extragonadal Germ Cell Tumors?',
#  'what research (or clinical trials) is being done for Extragonadal Germ Cell Tumors?',
#  'What is (are) Renal Cell Cancer?',
#  'What is (are) Chronic Neutrophilic Leukemia?',
#  'What are the treatments for Chronic Neutrophilic Leukemia?',
#  'Who is at risk for Small Cell Lung Cancer??',
#  'What are the symptoms of Small Cell Lung Cancer?',
#  'What is (are) Ovarian Low Malignant Potential Tumors?',
#  'What are the symptoms of Ovarian Low Malignant Potential Tumors?',
#  'What is the outlook for Ovarian Low Malignant Potential Tumors?',
#  'what research (or clinical trials) is being done for Ovarian Low Malignant Potential Tumors?',
#  'What is (are) Chronic Eosinophilic Leukemia?',
#  'What are the symptoms of Chronic Eosinophilic Leukemia?',
#  'What are the treatments for Chronic Eosinophilic Leukemia?',
#  'What is (are) Ovarian, Fallopian Tube, and Primary Peritoneal Cancer?',
#  'Who is at risk for Ovarian, Fallopian Tube, and Primary Peritoneal Cancer??',
#  'What is (are) Colon Cancer?',
#  'Who is at risk for Colon Cancer??',
#  'What are the symptoms of Colon Cancer?',
#  'What is the outlook for Colon Cancer?',
#  'What is (are) Liver (Hepatocellular) Cancer?',
#  'Who is at risk for Liver (Hepatocellular) Cancer??',
#  'What is (are) Testicular Cancer?',
#  'Who is at risk for Testicular Cancer??',
#  'What is the outlook for Testicular Cancer?',
#  'Who is at risk for Intraocular (Uveal) Melanoma??',
#  'What are the symptoms of Intraocular (Uveal) Melanoma?',
#  'What is the outlook for Intraocular (Uveal) Melanoma?',
#  'What is (are) Myelodysplastic/ Myeloproliferative Neoplasm, Unclassifiable?',
#  'What are the symptoms of Myelodysplastic/ Myeloproliferative Neoplasm, Unclassifiable?',
#  'What are the treatments for Myelodysplastic/ Myeloproliferative Neoplasm, Unclassifiable?',
#  'What is (are) Rectal Cancer?',
#  'Who is at risk for Rectal Cancer??',
#  'What are the symptoms of Rectal Cancer?',
#  'How to diagnose Rectal Cancer?',
#  'What is the outlook for Rectal Cancer?',
#  'what research (or clinical trials) is being done for Rectal Cancer?',
#  'What causes Childhood Astrocytomas?',
#  'Who is at risk for Childhood Astrocytomas??',
#  'What are the symptoms of Childhood Astrocytomas?',
#  'What is the outlook for Childhood Astrocytomas?',
#  'What are the stages of Childhood Astrocytomas?',
#  'what research (or clinical trials) is being done for Childhood Astrocytomas?',
#  'What is (are) Metastatic Squamous Neck Cancer with Occult Primary?',
#  'What are the symptoms of Metastatic Squamous Neck Cancer with Occult Primary?',
#  'What is the outlook for Metastatic Squamous Neck Cancer with Occult Primary?',
#  'What are the stages of Metastatic Squamous Neck Cancer with Occult Primary?',
#  'What is (are) Small Intestine Cancer?',
#  'Who is at risk for Small Intestine Cancer??',
#  'What are the symptoms of Small Intestine Cancer?',
#  'What is the outlook for Small Intestine Cancer?',
#  'What are the stages of Small Intestine Cancer?',
#  'Who is at risk for Non-Small Cell Lung Cancer??',
#  'What are the symptoms of Non-Small Cell Lung Cancer?',
#  'What is the outlook for Non-Small Cell Lung Cancer?',
#  'what research (or clinical trials) is being done for Non-Small Cell Lung Cancer?',
#  'How to diagnose Childhood Vascular Tumors?',
#  'what research (or clinical trials) is being done for Childhood Vascular Tumors?',
#  'What causes Childhood Brain Stem Glioma?',
#  'Who is at risk for Childhood Brain Stem Glioma??',
#  'What are the symptoms of Childhood Brain Stem Glioma?',
#  'How to diagnose Childhood Brain Stem Glioma?',
#  'What is the outlook for Childhood Brain Stem Glioma?',
#  'What are the stages of Childhood Brain Stem Glioma?',
#  'what research (or clinical trials) is being done for Childhood Brain Stem Glioma?',
#  'What is (are) Transitional Cell Cancer of the Renal Pelvis and Ureter?',
#  'What are the symptoms of Transitional Cell Cancer of the Renal Pelvis and Ureter?',
#  'What is the outlook for Transitional Cell Cancer of the Renal Pelvis and Ureter?',
#  'Who is at risk for Gestational Trophoblastic Disease??',
#  'What are the symptoms of Gestational Trophoblastic Disease?',
#  'What is the outlook for Gestational Trophoblastic Disease?',
#  'what research (or clinical trials) is being done for Gestational Trophoblastic Disease?',
#  'What are the treatments for Chronic Myelogenous Leukemia?',
#  'Who is at risk for Ovarian Epithelial, Fallopian Tube, and Primary Peritoneal Cancer??',
#  'Is Ovarian Epithelial, Fallopian Tube, and Primary Peritoneal Cancer inherited?',
#  'How to prevent Ovarian Epithelial, Fallopian Tube, and Primary Peritoneal Cancer?',
#  'What are the symptoms of Ovarian Epithelial, Fallopian Tube, and Primary Peritoneal Cancer?',
#  'What is the outlook for Ovarian Epithelial, Fallopian Tube, and Primary Peritoneal Cancer?',
#  'what research (or clinical trials) is being done for Oral Cavity and Oropharyngeal Cancer?',
#  'What is (are) Endometrial Cancer?',
#  'what research (or clinical trials) is being done for Endometrial Cancer?',
#  'What are the symptoms of AIDS-Related Lymphoma?',
#  'How to diagnose AIDS-Related Lymphoma?',
#  'What is the outlook for AIDS-Related Lymphoma?',
#  'What is (are) Pancreatic Cancer?',
#  'Who is at risk for Pancreatic Cancer??',
#  'What are the symptoms of Pancreatic Cancer?',
#  'What is the outlook for Pancreatic Cancer?',
#  'what research (or clinical trials) is being done for Pancreatic Cancer?',
#  'Who is at risk for Bile Duct Cancer (Cholangiocarcinoma)??',
#  'What are the symptoms of Bile Duct Cancer (Cholangiocarcinoma)?',
#  'What is the outlook for Bile Duct Cancer (Cholangiocarcinoma)?',
#  'what research (or clinical trials) is being done for Bile Duct Cancer (Cholangiocarcinoma)?',
#  'Who is at risk for Pancreatic Neuroendocrine Tumors (Islet Cell Tumors)??',
#  'What is the outlook for Pancreatic Neuroendocrine Tumors (Islet Cell Tumors)?',
#  'what research (or clinical trials) is being done for Ovarian, Fallopian Tube, and Primary Peritoneal Cancer?',
#  'What is (are) Laryngeal Cancer?',
#  'Who is at risk for Laryngeal Cancer??',
#  'What are the symptoms of Laryngeal Cancer?',
#  'What is the outlook for Laryngeal Cancer?',
#  'what research (or clinical trials) is being done for Laryngeal Cancer?',
#  'what research (or clinical trials) is being done for Colorectal Cancer?',
#  'Who is at risk for Plasma Cell Neoplasms (Including Multiple Myeloma)??',
#  'What is the outlook for Plasma Cell Neoplasms (Including Multiple Myeloma)?',
#  'What is (are) Salivary Gland Cancer?',
#  'Who is at risk for Salivary Gland Cancer??',
#  'What are the symptoms of Salivary Gland Cancer?',
#  'What is the outlook for Salivary Gland Cancer?',
#  'What are the symptoms of Childhood Non-Hodgkin Lymphoma?',
#  'What is the outlook for Childhood Non-Hodgkin Lymphoma?',
#  'What is (are) Adult Soft Tissue Sarcoma?',
#  'Who is at risk for Adult Soft Tissue Sarcoma??',
#  'What are the symptoms of Adult Soft Tissue Sarcoma?',
#  'What is the outlook for Adult Soft Tissue Sarcoma?',
#  'what research (or clinical trials) is being done for Adult Soft Tissue Sarcoma?',
#  'What is (are) Primary CNS Lymphoma?',
#  'Who is at risk for Primary CNS Lymphoma??',
#  'What is the outlook for Primary CNS Lymphoma?',
#  'Is Breast Cancer inherited?',
#  'What is the outlook for Prostate Cancer?',
#  'what research (or clinical trials) is being done for Prostate Cancer?',
#  'What is (are) Osteosarcoma and Malignant Fibrous Histiocytoma of Bone?',
#  'Who is at risk for Osteosarcoma and Malignant Fibrous Histiocytoma of Bone??',
#  'What are the symptoms of Osteosarcoma and Malignant Fibrous Histiocytoma of Bone?',
#  'What is the outlook for Osteosarcoma and Malignant Fibrous Histiocytoma of Bone?',
#  'Who is at risk for Oral Cavity and Oropharyngeal Cancer??',
#  'what research (or clinical trials) is being done for Adult Non-Hodgkin Lymphoma?',
#  'Who is at risk for Adult Non-Hodgkin Lymphoma??',
#  'What are the symptoms of Adult Non-Hodgkin Lymphoma?',
#  'What is the outlook for Adult Non-Hodgkin Lymphoma?',
#  'what research (or clinical trials) is being done for Liver (Hepatocellular) Cancer?',
#  'Who is at risk for Adult Central Nervous System Tumors??',
#  'What causes Adult Central Nervous System Tumors?',
#  'What are the symptoms of Adult Central Nervous System Tumors?',
#  'What is the outlook for Adult Central Nervous System Tumors?',
#  'What are the stages of Adult Central Nervous System Tumors?',
#  'What is (are) Essential Thrombocythemia?',
#  'What are the symptoms of Essential Thrombocythemia?',
#  'What is the outlook for Essential Thrombocythemia?',
#  'What are the treatments for Essential Thrombocythemia?',
#  'Who is at risk for Childhood Rhabdomyosarcoma??',
#  'What are the symptoms of Childhood Rhabdomyosarcoma?',
#  'What is the outlook for Childhood Rhabdomyosarcoma?',
#  'Who is at risk for Pituitary Tumors??',
#  'What is the outlook for Pituitary Tumors?',
#  'What are the stages of Pituitary Tumors?',
#  'What is (are) Nasopharyngeal Cancer?',
#  'Who is at risk for Nasopharyngeal Cancer??',
#  'What are the symptoms of Nasopharyngeal Cancer?',
#  'What is the outlook for Nasopharyngeal Cancer?',
#  'What is (are) Adult Primary Liver Cancer?',
#  'Who is at risk for Adult Primary Liver Cancer??',
#  'What are the symptoms of Adult Primary Liver Cancer?',
#  'What is the outlook for Adult Primary Liver Cancer?',
#  'Who is at risk for Childhood Central Nervous System Embryonal Tumors??',
#  'What are the symptoms of Childhood Central Nervous System Embryonal Tumors?',
#  'What is the outlook for Childhood Central Nervous System Embryonal Tumors?',
#  'Who is at risk for Adult Hodgkin Lymphoma??',
#  'What are the symptoms of Adult Hodgkin Lymphoma?',
#  'How to diagnose Adult Hodgkin Lymphoma?',
#  'What is the outlook for Adult Hodgkin Lymphoma?',
#  'What is (are) Parathyroid Cancer?',
#  'Who is at risk for Parathyroid Cancer??',
#  'What are the symptoms of Parathyroid Cancer?',
#  'What is the outlook for Parathyroid Cancer?',
#  'What is (are) Lip and Oral Cavity Cancer?',
#  'Who is at risk for Lip and Oral Cavity Cancer??',
#  'What are the symptoms of Lip and Oral Cavity Cancer?',
#  'What is the outlook for Lip and Oral Cavity Cancer?',
#  'What are the stages of Childhood Central Nervous System Germ Cell Tumors?',
#  'What causes Childhood Central Nervous System Germ Cell Tumors?',
#  'What are the symptoms of Childhood Central Nervous System Germ Cell Tumors?',
#  'What is the outlook for Childhood Central Nervous System Germ Cell Tumors?',
#  'what research (or clinical trials) is being done for Childhood Central Nervous System Germ Cell Tumors?',
#  'What is (are) Ovarian Germ Cell Tumors?',
#  'What are the symptoms of Ovarian Germ Cell Tumors?',
#  'How to diagnose Ovarian Germ Cell Tumors?',
#  'What is the outlook for Ovarian Germ Cell Tumors?',
#  'what research (or clinical trials) is being done for Ovarian Germ Cell Tumors?',
#  'what research (or clinical trials) is being done for Neuroblastoma?',
#  'Who is at risk for Childhood Hodgkin Lymphoma??',
#  'What are the symptoms of Childhood Hodgkin Lymphoma?',
#  'What is the outlook for Childhood Hodgkin Lymphoma?',
#  'what research (or clinical trials) is being done for Childhood Hodgkin Lymphoma?',
#  'What is (are) Penile Cancer?',
#  'Who is at risk for Penile Cancer??',
#  'What are the symptoms of Penile Cancer?',
#  'How to diagnose Penile Cancer?',
#  'What is the outlook for Penile Cancer?',
#  'What is (are) Oropharyngeal Cancer?',
#  'Who is at risk for Oropharyngeal Cancer??',
#  'What are the symptoms of Oropharyngeal Cancer?',
#  'What is the outlook for Oropharyngeal Cancer?',
#  'What is (are) Male Breast Cancer?',
#  'Who is at risk for Male Breast Cancer??',
#  'Is Male Breast Cancer inherited?',
#  'What are the symptoms of Male Breast Cancer?',
#  'What is the outlook for Male Breast Cancer?',
#  'What is (are) Primary Myelofibrosis?',
#  'What are the symptoms of Primary Myelofibrosis?',
#  'What is the outlook for Primary Myelofibrosis?',
#  'What are the treatments for Primary Myelofibrosis?',
#  'What are the symptoms of Urethral Cancer?',
#  'What is the outlook for Urethral Cancer?',
#  'Who is at risk for Melanoma??',
#  'What are the symptoms of Melanoma?',
#  'How to diagnose Melanoma?',
#  'What is the outlook for Melanoma?',
#  'what research (or clinical trials) is being done for Melanoma?',
#  'What is (are) Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor?',
#  'Who is at risk for Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor??',
#  'What are the symptoms of Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor?',
#  'What is the outlook for Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor?',
#  'What are the stages of Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor?',
#  'what research (or clinical trials) is being done for Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor?',
#  'What is (are) Retinoblastoma?',
#  'Who is at risk for Retinoblastoma??',
#  'What are the symptoms of Retinoblastoma?',
#  'What is the outlook for Retinoblastoma?',
#  'Who is at risk for Childhood Liver Cancer??',
#  'What are the symptoms of Childhood Liver Cancer?',
#  'What is the outlook for Childhood Liver Cancer?',
#  'How to diagnose Skin Cancer?',
#  'What is the outlook for Skin Cancer?',
#  'Who is at risk for Endometrial Cancer??',
#  'What are the symptoms of Endometrial Cancer?',
#  'How to diagnose Endometrial Cancer?',
#  'What is the outlook for Endometrial Cancer?',
#  'What is (are) Mycosis Fungoides and the Szary Syndrome?',
#  'What are the symptoms of Mycosis Fungoides and the Szary Syndrome?',
#  'What is the outlook for Mycosis Fungoides and the Szary Syndrome?',
#  'what research (or clinical trials) is being done for Mycosis Fungoides and the Szary Syndrome?',
#  'What is (are) Ewing Sarcoma?',
#  'What are the symptoms of Ewing Sarcoma?',
#  'What is the outlook for Ewing Sarcoma?',
#  'what research (or clinical trials) is being done for Ewing Sarcoma?',
#  'What causes Childhood Brain and Spinal Cord Tumors?',
#  'What are the symptoms of Childhood Brain and Spinal Cord Tumors?',
#  'What is the outlook for Childhood Brain and Spinal Cord Tumors?',
#  'what research (or clinical trials) is being done for Childhood Brain and Spinal Cord Tumors?',
#  'Who is at risk for Paranasal Sinus and Nasal Cavity Cancer??',
#  'What are the symptoms of Paranasal Sinus and Nasal Cavity Cancer?',
#  'What is the outlook for Paranasal Sinus and Nasal Cavity Cancer?',
#  'What is (are) Pregnancy and Substance Abuse?',
#  'Do you have information about Radiation Therapy',
#  'Do you have information about Rehabilitation',
#  'Do you have information about Iron',
#  'Do you have information about Pregnancy and Nutrition',
#  'What is (are) Interstitial Lung Diseases?',
#  'Do you have information about Volcanoes',
#  'What is (are) Hiccups?',
#  'What is (are) Premenstrual Syndrome?',
#  'What is (are) Dizziness and Vertigo?',
#  'What is (are) Oxygen Therapy?',
#  "What is (are) Huntington's Disease?",
#  'What is (are) Mouth Disorders?',
#  'What is (are) Vision Impairment and Blindness?',
#  'What is (are) Tremor?',
#  'What is (are) Nose Injuries and Disorders?',
#  'What is (are) Diphtheria?',
#  'What is (are) Esophageal Cancer?',
#  'Do you have information about HIV/AIDS Medicines',
#  'Do you have information about Rural Health Concerns',
#  'What is (are) Skin Conditions?',
#  'What is (are) Penis Disorders?',
#  'What is (are) Mumps?',
#  'Do you have information about Club Drugs',
#  'Do you have information about Newborn Screening',
#  'What is (are) Emphysema?',
#  'Do you have information about Surgery',
#  'What is (are) Ulcerative Colitis?',
#  'What is (are) Gallstones?',
#  'What is (are) Childbirth Problems?',
#  'Do you have information about Palliative Care',
#  'What is (are) Amyloidosis?',
#  'Do you have information about Tubal Ligation',
#  'Do you have information about Medicines and Children',
#  'What is (are) Rashes?',
#  'What is (are) Endocarditis?',
#  'What is (are) Bedwetting?',
#  'What is (are) Hip Injuries and Disorders?',
#  'Do you have information about Nutrition',
#  'What is (are) Hodgkin Disease?',
#  'What is (are) Fatigue?',
#  'What is (are) Speech and Communication Disorders?',
#  'What is (are) Frostbite?',
#  'Do you have information about International Health',
#  'What is (are) Heart Valve Diseases?',
#  'What is (are) Diabetic Nerve Problems?',
#  'Do you have information about Blood Count Tests',
#  'What is (are) Von Hippel-Lindau Disease?',
#  'Do you have information about Organ Donation',
#  'What is (are) Alpha-1 Antitrypsin Deficiency?',
#  'What is (are) Hepatitis B?',
#  'Do you have information about Noise',
#  'What is (are) Hiatal Hernia?',
#  'What is (are) Sprains and Strains?',
#  'Do you have information about Bowel Movement',
#  'What is (are) Choking?',
#  'What is (are) Dwarfism?',
#  'Do you have information about Sodium',
#  'What is (are) Lactose Intolerance?',
#  'What is (are) Vitiligo?',
#  'Do you have information about Native American Health',
#  'What is (are) Prescription Drug Abuse?',
#  'Do you have information about Cold and Cough Medicines',
#  'What is (are) Canker Sores?',
#  'Do you have information about Cocaine',
#  'What is (are) Hemophilia?',
#  'Do you have information about Water Pollution',
#  'What is (are) Bacterial Infections?',
#  'What is (are) Clostridium Difficile Infections?',
#  'Do you have information about Ozone',
#  'What is (are) Erectile Dysfunction?',
#  'What is (are) Chemical Emergencies?',
#  'What is (are) Tendinitis?',
#  'What is (are) Cat Scratch Disease?',
#  'Do you have information about Weight Control',
#  "What is (are) Bell's Palsy?",
#  'What is (are) Jaundice?',
#  'Do you have information about MRI Scans',
#  'What is (are) Lead Poisoning?',
#  'What is (are) Bleeding Disorders?',
#  'What is (are) Parasitic Diseases?',
#  'What is (are) Pulmonary Fibrosis?',
#  'Do you have information about Impaired Driving',
#  'What is (are) Sun Exposure?',
#  'Do you have information about Pregnancy and Medicines',
#  'What is (are) Aplastic Anemia?',
#  'Do you have information about Tornadoes',
#  'What is (are) Attention Deficit Hyperactivity Disorder?',
#  'What is (are) Mood Disorders?',
#  'What is (are) Degenerative Nerve Diseases?',
#  'What is (are) Genetic Disorders?',
#  'What is (are) Fever?',
#  'What is (are) Abdominal Pain?',
#  'What is (are) Transient Ischemic Attack?',
#  'Do you have information about Germs and Hygiene',
#  'What is (are) Aortic Aneurysm?',
#  'What is (are) Soft Tissue Sarcoma?',
#  'What is (are) Infections and Pregnancy?',
#  'What is (are) Eczema?',
#  'What is (are) Sinusitis?',
#  'What is (are) Scars?',
#  'Do you have information about Infant and Newborn Development',
#  'Do you have information about Exercise and Physical Fitness',
#  'What is (are) Heart Diseases?',
#  'What is (are) Neurologic Diseases?',
#  'What is (are) Rotator Cuff Injuries?',
#  'What is (are) Liver Cancer?',
#  'What is (are) Haemophilus Infections?',
#  'What is (are) Autism Spectrum Disorder?',
#  'What is (are) Heel Injuries and Disorders?',
#  "What is (are) Meniere's Disease?",
#  'What is (are) Bereavement?',
#  'Do you have information about Smokeless Tobacco',
#  'What is (are) Head Injuries?',
#  'What is (are) Child Behavior Disorders?',
#  'What is (are) Deep Vein Thrombosis?',
#  'What is (are) Mycobacterial Infections?',
#  'What is (are) Health Problems in Pregnancy?',
#  'What is (are) Respiratory Failure?',
#  'What is (are) Diabetic Kidney Problems?',
#  'Do you have information about Plastic and Cosmetic Surgery',
#  'What is (are) Cirrhosis?',
#  'What is (are) Endocrine Diseases?',
#  'What is (are) Emergency Medical Services?',
#  'Do you have information about DASH Diet',
#  'Do you have information about Common Infant and Newborn Problems',
#  'What is (are) Sexual Assault?',
#  'Do you have information about Carbohydrates',
#  'Do you have information about Nutritional Support',
#  'Do you have information about Child Safety',
#  'Do you have information about Teen Health',
#  'What is (are) Autonomic Nervous System Disorders?',
#  'Do you have information about Fires',
#  'What is (are) Hantavirus Infections?',
#  'What is (are) Eating Disorders?',
#  'What is (are) Foreign Bodies?',
#  'What is (are) Kidney Failure?',
#  'Do you have information about Toddler Development',
#  'What is (are) Breathing Problems?',
#  'Do you have information about Biodefense and Bioterrorism',
#  'What is (are) Adrenal Gland Disorders?',
#  'Do you have information about Antioxidants',
#  'Do you have information about Body Weight',
#  'Do you have information about Antibiotics',
#  'What is (are) Hemorrhagic Stroke?',
#  'What is (are) Tailbone Disorders?',
#  'What is (are) Mitral Valve Prolapse?',
#  'What is (are) Motion Sickness?',
#  'What is (are) Spinal Stenosis?',
#  'Do you have information about Motor Vehicle Safety',
#  'Do you have information about Healthy Aging',
#  'Do you have information about Colonoscopy',
#  'What is (are) Ovarian Cysts?',
#  'Do you have information about Mercury',
#  'What is (are) Diarrhea?',
#  'Do you have information about Cochlear Implants',
#  'Do you have information about Nutrition for Seniors',
#  'What is (are) Malnutrition?',
#  'What is (are) Food Allergy?',
#  'Do you have information about B Vitamins',
#  'Do you have information about Pain Relievers',
#  'What is (are) Uterine Cancer?',
#  'What is (are) Wilson Disease?',
#  'What is (are) Tick Bites?',
#  'What is (are) Speech and Language Problems in Children?',
#  'Do you have information about Safety',
#  'Do you have information about Diets',
#  'What is (are) Diabetic Eye Problems?',
#  'What is (are) Poison Ivy, Oak and Sumac?',
#  'What is (are) Animal Bites?',
#  'Do you have information about Health Screening',
#  'What is (are) Arm Injuries and Disorders?',
#  'Do you have information about Vegetarian Diet',
#  'What is (are) Small Intestine Disorders?',
#  'Do you have information about Asian American Health',
#  'What is (are) Sleep Disorders?',
#  'What is (are) Turner Syndrome?',
#  'What is (are) Shock?',
#  'Do you have information about Artificial Limbs',
#  'Do you have information about Diabetic Diet',
#  'Do you have information about Antidepressants',
#  'What is (are) Restless Legs?',
#  'What is (are) Eosinophilic Disorders?',
#  'What is (are) Wilms Tumor?',
#  'Do you have information about Hazardous Waste',
#  'Do you have information about Medication Errors',
#  'Do you have information about Tonsils and Adenoids',
#  'What is (are) Compulsive Gambling?',
#  'What is (are) Coping with Chronic Illness?',
#  'Do you have information about Minerals',
#  'What is (are) Botulism?',
#  'What is (are) Hypoglycemia?',
#  'What is (are) Stuttering?',
#  'Do you have information about Gun Safety',
#  'What is (are) Movement Disorders?',
#  "What is (are) Crohn's Disease?",
#  'What is (are) Bullying?',
#  'What is (are) Diabetes Type 2?',
#  'Do you have information about Native Hawaiian and Pacific Islander Health',
#  'Do you have information about Vitamin D',
#  'Do you have information about Liver Function Tests',
#  'Do you have information about Underage Drinking',
#  'What is (are) Chiari Malformation?',
#  'What is (are) Prediabetes?',
#  'What is (are) Lymphedema?',
#  'Do you have information about Dietary Fats',
#  'What is (are) Seasonal Affective Disorder?',
#  'Do you have information about Caregivers',
#  'What is (are) Male Infertility?',
#  'Do you have information about Medicare Prescription Drug Coverage',
#  'What is (are) Childhood Brain Tumors?',
#  'What is (are) Esophagus Disorders?',
#  'What is (are) Pulmonary Hypertension?',
#  "Do you have information about Men's Health",
#  'What is (are) Chickenpox?',
#  'What is (are) Hearing Disorders and Deafness?',
#  'Do you have information about Hospice Care',
#  'Do you have information about Eye Wear',
#  'What is (are) Temporomandibular Joint Dysfunction?',
#  'Do you have information about Indoor Air Pollution',
#  'What is (are) Polymyalgia Rheumatica?',
#  'Do you have information about Understanding Medical Research',
#  'What is (are) Alcoholism and Alcohol Abuse?',
#  'What is (are) Nausea and Vomiting?',
#  'What is (are) Pleural Disorders?',
#  'Do you have information about Patient Safety',
#  'Do you have information about Vitamin C',
#  'What is (are) Poisoning?',
#  'What is (are) Constipation?',
#  'Do you have information about Cholesterol',
#  'Do you have information about HIV/AIDS in Women',
#  'What is (are) Carpal Tunnel Syndrome?',
#  'Do you have information about Air Pollution',
#  'What is (are) Tetanus, Diphtheria, and Pertussis Vaccines?',
#  'What is (are) Dementia?',
#  'Do you have information about Alcohol',
#  'What is (are) Polycystic Ovary Syndrome?',
#  'Do you have information about Pancreas Transplantation',
#  'What is (are) Anxiety?',
#  'What is (are) Birth Defects?',
#  'What is (are) Spina Bifida?',
#  'What is (are) Blood Disorders?',
#  'What is (are) Sepsis?',
#  'What is (are) After Surgery?',
#  'Do you have information about Water Safety (Recreational)',
#  'What is (are) Bronchial Disorders?',
#  'What is (are) Pituitary Disorders?',
#  'Do you have information about Coronary Artery Bypass Surgery',
#  'What is (are) Bipolar Disorder?',
#  'What is (are) Parathyroid Disorders?',
#  'What is (are) Fractures?',
#  'What is (are) Sciatica?',
#  'Do you have information about Urinalysis',
#  'What is (are) Paralysis?',
#  'What is (are) Lewy Body Disease?',
#  'Do you have information about Angioplasty',
#  'Do you have information about Laboratory Tests',
#  'What is (are) Uterine Diseases?',
#  'What is (are) Teenage Pregnancy?',
#  'What is (are) Vascular Diseases?',
#  'Do you have information about Blood Clots',
#  'What is (are) Dentures?',
#  'What is (are) Inhalation Injuries?',
#  'What is (are) Prader-Willi Syndrome?',
#  'Do you have information about Lice',
#  'What is (are) Indigestion?',
#  'Do you have information about Diagnostic Imaging',
#  'What is (are) Scleroderma?',
#  'What is (are) Shoulder Injuries and Disorders?',
#  'Do you have information about Cardiac Rehabilitation',
#  'Do you have information about Blood Thinners',
#  'Do you have information about Infant and Newborn Care',
#  'What is (are) Hay Fever?',
#  'What is (are) Kidney Cancer?',
#  'What is (are) Cervical Cancer?',
#  'Do you have information about Islet Cell Transplantation',
#  'What is (are) Hemochromatosis?',
#  'What is (are) Viral Infections?',
#  'Do you have information about Laser Eye Surgery',
#  'What is (are) Schizophrenia?',
#  'What is (are) Tooth Decay?',
#  'What is (are) Premature Ovarian Failure?',
#  'What is (are) Thalassemia?',
#  'Do you have information about Breast Reconstruction',
#  'What is (are) Joint Disorders?',
#  'What is (are) Bleeding?',
#  'What is (are) Parenting?',
#  "Do you have information about Traveler's Health",
#  'Do you have information about Hysterectomy',
#  'Do you have information about Cancer Chemotherapy',
#  'What is (are) Breast Diseases?',
#  'What is (are) Rubella?',
#  'What is (are) Anaphylaxis?',
#  'What is (are) Connective Tissue Disorders?',
#  'What is (are) Down Syndrome?',
#  'What is (are) Immune System and Disorders?',
#  "What is (are) Behcet's Syndrome?",
#  'What is (are) Hepatitis?',
#  'Do you have information about Genetic Testing',
#  'What is (are) Ureteral Disorders?',
#  'What is (are) Diabetic Heart Disease?',
#  'What is (are) Porphyria?',
#  'What is (are) Common Cold?',
#  'What is (are) Pancreatic Diseases?',
#  'Do you have information about Inhalants',
#  'What is (are) Ehlers-Danlos Syndrome?',
#  'What is (are) Listeria Infections?',
#  'What is (are) Ankylosing Spondylitis?',
#  'What is (are) HIV/AIDS?',
#  'Do you have information about Limb Loss',
#  'What is (are) Cervix Disorders?',
#  'What is (are) Hair Problems?',
#  'Do you have information about Breastfeeding',
#  'Do you have information about Farm Health and Safety',
#  'Do you have information about Clinical Trials',
#  'Do you have information about Flu Shot',
#  'What is (are) Toxoplasmosis?',
#  'What is (are) Tumors and Pregnancy?',
#  'What is (are) Bone Marrow Diseases?',
#  'What is (are) Urethral Disorders?',
#  'What is (are) High Blood Pressure in Pregnancy?',
#  'Do you have information about Patient Rights',
#  "Do you have information about Seniors' Health",
#  'Do you have information about A1C',
#  'What is (are) Menopause?',
#  'What is (are) Scabies?',
#  'Do you have information about Medicare',
#  'Do you have information about Hormone Replacement Therapy',
#  'What is (are) Blood Pressure Medicines?',
#  'Do you have information about CT Scans',
#  'Do you have information about Talking With Your Doctor',
#  'Do you have information about Prostate Cancer Screening',
#  'What is (are) Mobility Aids?',
#  'What is (are) Rett Syndrome?',
#  'What is (are) Neurofibromatosis?',
#  'What is (are) Multiple Myeloma?',
#  'Do you have information about Child Nutrition',
#  'What is (are) Cardiomyopathy?',
#  'What is (are) Tuberous Sclerosis?',
#  'Do you have information about Blood Sugar',
#  'Do you have information about Bone Marrow Transplantation',
#  'Do you have information about Diabetes Medicines',
#  'Do you have information about Hormones',
#  'What is (are) Ear Infections?',
#  'What is (are) Pressure Sores?',
#  'Do you have information about Mastectomy',
#  'Do you have information about Advance Directives',
#  'Do you have information about Fire Safety',
#  'What is (are) Chikungunya?',
#  'What is (are) Testicular Disorders?',
#  'What is (are) Neck Injuries and Disorders?',
#  'Do you have information about Over-the-Counter Medicines',
#  'What is (are) Hepatitis C?',
#  'What is (are) Pheochromocytoma?',
#  'Do you have information about Sports Safety',
#  'What is (are) Phenylketonuria?',
#  'Do you have information about Cosmetic Dentistry',
#  'Do you have information about Health Literacy',
#  'What is (are) Adrenal Gland Cancer?',
#  'Do you have information about Bone Density',
#  'Do you have information about Radiation Emergencies',
#  'What is (are) Sports Injuries?',
#  'Do you have information about Medicines',
#  'What is (are) Childbirth?',
#  'What is (are) Peritoneal Disorders?',
#  'What is (are) Arteriovenous Malformations?',
#  'What is (are) Bone Diseases?',
#  "What is (are) Legionnaires' Disease?",
#  'Do you have information about Dialysis',
#  'What is (are) Coronary Artery Disease?',
#  'What is (are) Tongue Disorders?',
#  'Do you have information about Toddler Health',
#  'What is (are) Complex Regional Pain Syndrome?',
#  'What is (are) Acute Bronchitis?',
#  'What is (are) Dislocations?',
#  'What is (are) Migraine?',
#  'Do you have information about Blood',
#  'Do you have information about Medical Device Safety',
#  'What is (are) Zika Virus?',
#  'Do you have information about Sports Fitness',
#  'What is (are) Bladder Cancer?',
#  'What is (are) Cryptosporidiosis?',
#  'Do you have information about Hip Replacement',
#  'What is (are) Dengue?',
#  'What is (are) Peripheral Nerve Disorders?',
#  'What is (are) Fibromyalgia?',
#  'What is (are) Guillain-Barre Syndrome?',
#  'What is (are) Fragile X Syndrome?',
#  'What is (are) Vaginal Bleeding?',
#  'What is (are) Foot Injuries and Disorders?',
#  'What is (are) Pelvic Inflammatory Disease?',
#  "Do you have information about Children's Health",
#  'What is (are) Herpes Simplex?',
#  'What is (are) Cartilage Disorders?',
#  'What is (are) Irritable Bowel Syndrome?',
#  'What is (are) Smallpox?',
#  'What is (are) Spine Injuries and Disorders?',
#  'What is (are) Mental Disorders?',
#  'What is (are) GERD?',
#  'Do you have information about Quitting Smoking',
#  'Do you have information about Prenatal Testing',
#  'What is (are) Voice Disorders?',
#  'What is (are) Benign Tumors?',
#  'What is (are) Eye Infections?',
#  'What is (are) Myasthenia Gravis?',
#  'Do you have information about School Health',
#  'What is (are) Enlarged Prostate (BPH)?',
#  'What is (are) Stomach Disorders?',
#  'What is (are) Itching?',
#  'Do you have information about Healthy Living',
#  'What is (are) Mesothelioma?',
#  'What is (are) Bile Duct Diseases?',
#  'Do you have information about Infection Control',
#  'Do you have information about Potassium',
#  'What is (are) Warts?',
#  'Do you have information about Heart Transplantation',
#  'Do you have information about Prenatal Care',
#  'What is (are) Throat Disorders?',
#  'What is (are) Pinworms?',
#  'What is (are) Skin Pigmentation Disorders?',
#  'Do you have information about Health Insurance',
#  'Do you have information about Climate Change',
#  'Do you have information about Immunization',
#  'What is (are) Cancer?',
#  'What is (are) Refractive Errors?',
#  'Do you have information about Cesarean Section',
#  'What is (are) Digestive Diseases?',
#  'Do you have information about Critical Care',
#  'What is (are) Tooth Disorders?',
#  'What is (are) Genetic Brain Disorders?',
#  'What is (are) Sarcoidosis?',
#  'What is (are) Trigeminal Neuralgia?',
#  'What is (are) Neuromuscular Disorders?',
#  'What is (are) Snoring?',
#  'What is (are) Whooping Cough?',
#  'What is (are) Varicose Veins?',
#  'What is (are) Scoliosis?',
#  'What is (are) Thymus Cancer?',
#  'What is (are) Hemorrhagic Fevers?',
#  'What is (are) Hand Injuries and Disorders?',
#  'Do you have information about College Health',
#  'What is (are) Cytomegalovirus Infections?',
#  'What is (are) Gangrene?',
#  'What is (are) Brain Aneurysm?',
#  'What is (are) Corneal Disorders?',
#  'Do you have information about Winter Weather Emergencies',
#  'What is (are) Headache?',
#  'What is (are) Eye Movement Disorders?',
#  'What is (are) Croup?',
#  'Do you have information about Assistive Devices',
#  "What is (are) Alzheimer's Caregivers?",
#  'Do you have information about Childhood Immunization',
#  'Do you have information about Dietary Fiber',
#  'What is (are) Colonic Polyps?',
#  'Do you have information about Drug Safety',
#  'What is (are) Thyroid Cancer?',
#  'Do you have information about Dietary Supplements',
#  'Do you have information about Veterans and Military Health',
#  'What is (are) Ischemic Stroke?',
#  'What is (are) Twins, Triplets, Multiple Births?',
#  'Do you have information about Vasectomy',
#  'What is (are) Living with HIV/AIDS?',
#  'What is (are) Impetigo?',
#  'Do you have information about End of Life Issues',
#  'What is (are) Managed Care?',
#  'What is (are) Cancer in Children?',
#  'What is (are) Allergy?',
#  'Do you have information about Medicaid',
#  'What is (are) Stomach Cancer?',
#  'What is (are) Falls?',
#  'What is (are) Hair Loss?',
#  'What is (are) Veterans and Military Family Health?',
#  'What is (are) Domestic Violence?',
#  'What is (are) Latex Allergy?',
#  'What is (are) Cough?',
#  'What is (are) Postpartum Depression?',
#  'Do you have information about Health Occupations',
#  'What is (are) Retinal Detachment?',
#  'Do you have information about Oil Spills',
#  'What is (are) Sleep Apnea?',
#  'What is (are) Prostate Diseases?',
#  'What is (are) Animal Diseases and Your Health?',
#  'What is (are) Platelet Disorders?',
#  'Do you have information about Nursing Homes',
#  'What is (are) Tuberculosis?',
#  ...]
